# %%
# Install necessary libraries
# !pip install pandas numpy matplotlib seaborn requests beautifulsoup4
# Out:
# Requirement already satisfied: pandas in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (2.2.6)
# Requirement already satisfied: matplotlib in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (3.10.6)
# Requirement already satisfied: seaborn in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: requests in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (4.13.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: six>=1.5 in c:\users\csaaj\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd            # For data manipulation
import numpy as np             # For numerical operations
import matplotlib.pyplot as plt # For basic plotting
import seaborn as sns          # For advanced visualization
import requests                # For web scraping
from bs4 import BeautifulSoup  # For parsing HTML

# %%
###Web Scraping

# %%
url = "http://quotes.toscrape.com"
response = requests.get(url)

# %%
# 2. Parse the content
soup = BeautifulSoup(response.text, 'html.parser')

# %%
#Extract data (Find all quotes)
quotes = [q.text for q in soup.find_all('span', class_='text')]
authors = [a.text for a in soup.find_all('small', class_='author')]

# %%
# 4. Create the DataFrame
df = pd.DataFrame({'Quote': quotes, 'Author': authors})

# %%
df.head()
# Out:
#                                                Quote           Author
# 0  “The world as we have created it is a process ...  Albert Einstein
# 1  “It is our choices, Harry, that show what we t...     J.K. Rowling
# 2  “There are only two ways to live your life. On...  Albert Einstein
# 3  “The person, be it gentleman or lady, who has ...      Jane Austen
# 4  “Imperfection is beauty, madness is genius and...   Marilyn Monroe

# %%
print(len(quotes))
print(len(authors))
# Out:
# 10
# 10
